# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr  # see http://xarray.pydata.org/en/stable/plotting.html
import xmitgcm as xgcm
# %matplotlib notebook

# %%
fig2, ax2 = plt.subplots()


for nn, qdatad in  enumerate(['../runs/LinData/', '../runs/linDragPkg2/', '../runs/spreadstress/', 
                              '../runs/quadSpread/', '../runs/QuadData/', '../runs/QuadPkg/']): # , '../runs/QuadData', '../runs/QuadData2']:
    with xgcm.open_mdsdataset(qdatad, endian='<', prefix=['statevars', 'statevars2d'], geometry='cartesian', 
                              ) as ds:
        # print(ds)
        ds = ds.isel(time=-1)
        ax2.plot(ds.UVEL[:, 5, 5], ds.Z, label=qdatad[8:-1])

ax2.legend()
        #ax.plot(ds.VVEL.mean(dim=('Z', 'YG', 'XC')))
# Out:
# <img src="data:image/png;base64,..." width="640">
